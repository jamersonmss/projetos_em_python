# %%
from sklearn.datasets import load_iris
iris = load_iris()
x = iris.data
y = iris.target
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25)

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics

valores_performance = {}
k = 1

while k <= 25:
    knn = KNeighborsClassifier(n_neighbors=k)
    knn.fit(x_train,y_train)
    previsoes = knn.predict(x_test)
    acertos = metrics.accuracy_score(y_test,previsoes)
    valores_performance[k] = round(acertos,4)
    k += 1
    
print(valores_performance)
# Out:
# {1: 0.9474, 2: 0.9474, 3: 0.9474, 4: 0.9474, 5: 0.9737, 6: 0.9474, 7: 0.9737, 8: 0.9474, 9: 1.0, 10: 0.9737, 11: 0.9737, 12: 0.9474, 13: 0.9737, 14: 0.9737, 15: 0.9737, 16: 0.9737, 17: 1.0, 18: 0.9474, 19: 1.0, 20: 0.9737, 21: 1.0, 22: 0.9737, 23: 0.9737, 24: 0.9737, 25: 0.9737}

# %%
import matplotlib.pyplot as plt

plt.plot(list(valores_performance.keys()),list(valores_performance.values()))
plt.xlabel('Valores de k')
plt.ylabel('Performance')
plt.show()

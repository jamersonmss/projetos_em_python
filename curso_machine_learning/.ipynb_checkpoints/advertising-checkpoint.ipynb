# %%
import pandas as pd

publi = pd.read_csv('https://raw.githubusercontent.com/XMUR/ISLR-1/master/Advertising.csv',index_col=0)
publi.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
print(publi.shape)
# Out:
# (200, 4)

# %%
x = publi[['TV','Radio','Newspaper']]
y = publi['Sales']

# %%
x.shape
# Out:
# (200, 3)

# %%
y.shape
# Out:
# (200,)

# %%
import seaborn as sns
sns.pairplot(publi, x_vars=['TV','Radio','Newspaper'], y_vars='Sales', height=7, kind='reg')

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.3)

# %% [markdown]
# ## Importação do modelo de regressão linear

# %%
from sklearn.linear_model import LinearRegression
reglin = LinearRegression()
reglin.fit(x_train.values, y_train.values)
# Out:
# LinearRegression()

# %% [markdown]
# ### Coeficientes: Aumento nas vendas para cada 1un investido em publicidade

# %%
list(zip(['TV','Radio','Newspaper'],reglin.coef_))
# Out:
# [('TV', 0.048318087491826776),
#  ('Radio', 0.18056988317424624),
#  ('Newspaper', -0.0022877582857795953)]

# %% [markdown]
# ### Previsão

# %%
y_prev = reglin.predict(x_test.values)
print(y_prev)
# Out:
# [12.81270448 20.58803663 14.25621849  7.81400496 19.24681137  9.90433662
#  20.69801903  3.59526054 16.62179164 18.43797215 17.52594535 15.07914253
#   4.3800721  16.0930245  14.2727109  10.03445648  9.00985056 23.44814907
#  15.2277788  16.53352166  5.92909047  9.51035468 11.40567397 17.5697746
#   9.62624113 10.05467777 11.9461894  19.83373596 12.11953365  6.60491496
#  16.27814557 21.85828655 16.79959205 19.21403641  4.30193046 17.3402064
#  18.28897243 24.91633341 11.76350309 12.40963753 16.54164394 17.85984939
#  13.29529142 20.80590642 21.10936699 17.29761533 15.06445485 12.12328182
#  12.19234479 15.14067405  8.55718605 14.06168878 12.12845375  8.84291731
#  15.70224545 10.61776939 14.13272662 12.63088541 18.79097747 13.35527586]

# %% [markdown]
# ### Avaliação da Performance

# %% [markdown]
# ### MAE (Mean absolute error)

# %%
from sklearn import metrics

# %%
print(metrics.mean_absolute_error(y_test,y_prev))
# Out:
# 1.298325783911026

# %% [markdown]
# ### MSE (Mean squared error)

# %%
print(metrics.mean_squared_error(y_test,y_prev))
# Out:
# 2.9070283988124292

# %% [markdown]
# ### RMSE (Root mean squared error)

# %%
import numpy as np
print(np.sqrt(metrics.mean_squared_error(y_test,y_prev)))
# Out:
# 1.7050009967188962
